# %% [markdown]
# # Lab 1 part 1
# Group members:
# 1. Swati Nair (UBitName: swatishr; UB Person No: 50246994)
# 2. Bhavik Gala (UBIT Name: bhavikna;  UB Person No: 50248608)

# %% [markdown]
# Problem 1: Define two synthetic vectors of data representing sales over 12 months for 2 items.
# Compare the two using lines graphs.

# %%
sales1<-c(12,14,16,29,30,45,19,20,16, 19, 34, 20)
sales2<-rpois(12,34)
par(bg="cornsilk")
plot(sales1, col="blue", type="o", ylim=c(0,100), xlab="Month", ylab="Sales")
title(main = "Sales by Month")
lines(sales2, type="o", pch=22, lty=2, col="red")
grid(nx=NA, ny=NULL)
legend("topright", inset=.05, c("Sales1","Sales2"), fill=c("blue","red"), horiz=TRUE)
# Out:
# Plot with title "Sales by Month"

# %% [markdown]
# Problem 2: The sales data is available in a table in a text file.
# Read it in and draw a side-by-side histogram to compare the performance.

# %%
sales<-read.table(file.choose(), header=T)

# %%
sales
# Out:
#    Sales1 Sales2
# 1  34     45
# 2  23     23
# 3  12     56
# 4  29     34
# 5  34     45
# 6  34     56
# 7  12     89
# 8  80     36
# 9  80     44
# 10 56     66
# 11 55     60
# 12 45     23

# %%
barplot(as.matrix(sales), main="Sales Data", ylab= "Total",beside=T, col=rainbow(5))
# Out:
# Plot with title "Sales Data"

# %% [markdown]
# Problem 3: Use boxplot to compare the two sales data.

# %%
fn <- boxplot(sales, col=c("pink","green"))$stats
text(1.45, fn[3,2], paste("Median =", fn[3,2]), adj=0, cex=.7)
text(0.45, fn[3,1],paste("Median =", fn[3,1]), adj=0, cex=.7)
grid(nx=NA, ny=NULL)
# Out:
# plot without title

# %% [markdown]
# Problem 4: Download csv data from the web and analyze using the methods above.

# %%
fb1<-read.csv(file.choose())

# %%
aapl1<-read.csv(file.choose())

# %%
par(bg="cornsilk")
plot(aapl1$Adj.Close, col="blue", type="o", ylim=c(150,200), xlab="Days", ylab="Price" )
lines(fb1$Adj.Close, type="o", pch=22, lty=2, col="red")
legend("topright", inset=0.05, c("Apple","Facebook"), fill=c("blue","red"), horiz=TRUE)
# Out:
# plot without title

# %%
hist(aapl1$Adj.Close, col=rainbow(8))
# Out:
# Plot with title "Histogram of aapl1$Adj.Close"

# %% [markdown]
# Problem 5: Data sets available with R: R community has created a lot of data for others to use.
# Examine the data sets already available with R. data(), attach(),detach(), head(), summary()

# %%
data(package = "datasets")

# %%
summary(BOD)
# Out:
#       Time           demand
#  Min.   :1.000   Min.   : 8.30
#  1st Qu.:2.250   1st Qu.:11.62
#  Median :3.500   Median :15.80
#  Mean   :3.667   Mean   :14.83
#  3rd Qu.:4.750   3rd Qu.:18.25
#  Max.   :7.000   Max.   :19.80

# %%
BOD
# Out:
#   Time demand
# 1 1     8.3
# 2 2    10.3
# 3 3    19.0
# 4 4    16.0
# 5 5    15.6
# 6 7    19.8

# %%
summary(BOD$Time)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.000   2.250   3.500   3.667   4.750   7.000

# %%
summary(Time)
# Out:
# Error in summary(Time): object 'Time' not found
# Traceback:
#
# 1. summary(Time)

# %%
attach(BOD)

# %%
summary(Time)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.000   2.250   3.500   3.667   4.750   7.000

# %%
head(BOD)
# Out:
#   Time demand
# 1 1     8.3
# 2 2    10.3
# 3 3    19.0
# 4 4    16.0
# 5 5    15.6
# 6 7    19.8

# %%
summary(Time)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.000   2.250   3.500   3.667   4.750   7.000

# %%
detach(BOD)

# %%
summary(Time)
# Out:
# Error in summary(Time): object 'Time' not found
# Traceback:
#
# 1. summary(Time)

# %%
summary(BOD$Time)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.000   2.250   3.500   3.667   4.750   7.000

# %%
library(datasets)

# %%
summary(mpg)
# Out:
#    Length     Class      Mode
#         1 character character

# %%
install.packages('ggplot2', repos='http://cran.us.r-project.org')
# Out:
# package 'ggplot2' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\swati\AppData\Local\Temp\RtmpA51HaS\downloaded_packages

# %%
library(datasets)

# %%
summary(mpg)
# Out:
#    Length     Class      Mode
#         1 character character

# %%
data()

# %%
library(help=datasets)

# %%
library(datasets)

# %%
head(uspop)
# Out:
# [1]  3.93  5.31  7.24  9.64 12.90 17.10

# %%
uspop
# Out:
# Time Series:
# Start = 1790
# End = 1970
# Frequency = 0.1
#  [1]   3.93   5.31   7.24   9.64  12.90  17.10  23.20  31.40  39.80  50.20
# [11]  62.90  76.00  92.00 105.70 122.80 131.70 151.30 179.30 203.20

# %%
plot(uspop)
# Out:
# plot without title

# %%
library("ggmap")

# %%
data(mpg)

# %%
attach(mpg)

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
summary(mpg)
# Out:
#  manufacturer          model               displ            year
#  Length:234         Length:234         Min.   :1.600   Min.   :1999
#  Class :character   Class :character   1st Qu.:2.400   1st Qu.:1999
#  Mode  :character   Mode  :character   Median :3.300   Median :2004
#                                        Mean   :3.472   Mean   :2004
#                                        3rd Qu.:4.600   3rd Qu.:2008
#                                        Max.   :7.000   Max.   :2008
#       cyl           trans               drv                 cty
#  Min.   :4.000   Length:234         Length:234         Min.   : 9.00
#  1st Qu.:4.000   Class :character   Class :character   1st Qu.:14.00
#  Median :6.000   Mode  :character   Mode  :character   Median :17.00
#  Mean   :5.889                                         Mean   :16.86
#  3rd Qu.:8.000                                         3rd Qu.:19.00
#  Max.   :8.000                                         Max.   :35.00
# ...

# %%
summary(model)
# Out:
#    Length     Class      Mode
#       234 character character

# %%
head(model)
# Out:
# [1] "a4" "a4" "a4" "a4" "a4" "a4"

# %%
detach(mpg)

# %%
head(model)
# Out:
# Error in head(model): object 'model' not found
# Traceback:
#
# 1. head(model)

# %%
head(mpg$model)
# Out:
# [1] "a4" "a4" "a4" "a4" "a4" "a4"

# %%
#Problem 6: Accessing external APIs:
#List a collection of cities you have visited and plot it on a map.

# %%
install.packages('ggmap', repos='http://cran.us.r-project.org')
# Out:
# package 'ggmap' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\swati\AppData\Local\Temp\RtmpOs7F7D\downloaded_packages

# %%
install.packages('maptools', repos='http://cran.us.r-project.org')
# Out:
# package 'maptools' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\swati\AppData\Local\Temp\RtmpOs7F7D\downloaded_packages

# %%
install.packages('maps', repos='http://cran.us.r-project.org')
# Out:
# package 'maps' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\swati\AppData\Local\Temp\RtmpOs7F7D\downloaded_packages

# %%
library("ggmap")
library("maptools")
library(maps)
visited <- c("SFO", "Chennai", "London,UK", "Melbourne", "Lima,Peru", "Johannesbury,SA")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("world", fill=TRUE, col="white", bg="lightblue", ylim=c(-60, 90), mar=c(0,0,0,0))
points(visit.x,visit.y, col="red", pch=36)
# Out:
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=SFO&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Chennai&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=London,UK&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Melbourne&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Lima,Peru&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Johannesbury,SA&sensor=false
# plot without title

# %%
library("ggmap")
library("maptools")
library(maps)
visited <- c("SFO", "New York", "Buffalo, NY", "Dallas,TX")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("state", fill=TRUE, col=rainbow(50), bg="lightblue", mar=c(0,0,0,0))
points(visit.x,visit.y, col="yellow", pch=36)
# Out:
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=SFO&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20York&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Buffalo,%20NY&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Dallas,TX&sensor=false
# plot without title

# %%
#Problem 7: Attach and explore mtcars. 
#Draw scatter plots of the dependent variables (i) 5 variables (ii) 4 variables.

# %%
library('lattice')
# Out:
# Warning message:
# "package 'lattice' was built under R version 3.4.3"

# %%
splom(mtcars[c(1,3,4,5,6)], main="MTCARS Data")
# Out:
# plot without title

# %%
splom(mtcars[c(1,3,4,6)], main="MTCARS Data")
# Out:
# plot without title

# %%
splom(mtcars[c(1,3,4,6)], col=rainbow(4),main="MTCARS Data")
# Out:
# plot without title

# %%
splom(rock[c(1,2,3,4)], main="ROCK Data")
# Out:
# plot without title

# %% [markdown]
# Problem 8: Working with ggplot2
#
# Citation: http://r-statistics.co/Top50-Ggplot2-Visualizations-MasterList-R-Code.html

# %%
install.packages('ggalt', repos='http://cran.us.r-project.org')
# Out:
# also installing the dependencies 'extrafontdb', 'Rttf2pt1', 'crosstalk', 'proj4', 'ash', 'extrafont', 'plotly'
# package 'extrafontdb' successfully unpacked and MD5 sums checked
# package 'Rttf2pt1' successfully unpacked and MD5 sums checked
# package 'crosstalk' successfully unpacked and MD5 sums checked
# package 'proj4' successfully unpacked and MD5 sums checked
# package 'ash' successfully unpacked and MD5 sums checked
# package 'extrafont' successfully unpacked and MD5 sums checked
# package 'plotly' successfully unpacked and MD5 sums checked
# package 'ggalt' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\swati\AppData\Local\Temp\Rtmp0WNGla\downloaded_packages

# %%
#Scatterplot using ggplot2 geom_point, geom_smooth to draw a smoothing line, 
# geom_encircle to encircle some part of the plot
options(scipen=999)  # turn-off scientific notation like 1e+48
library(ggplot2)
library(ggalt)
midwest_select <- midwest[midwest$poptotal > 350000 & 
                            midwest$poptotal <= 500000 & 
                            midwest$area > 0.01 & 
                            midwest$area < 0.1, ]
theme_set(theme_bw())
data("midwest", package = "ggplot2")
gg <- ggplot(midwest, aes(x=area, y=poptotal)) + 
  geom_point(aes(col=state, size=popdensity)) + 
  geom_smooth(method="loess", se=F) + 
  geom_encircle(aes(x=area, y=poptotal), 
                data=midwest_select, 
                color="red", 
                size=2, 
                expand=0.08) +
  xlim(c(0, 0.1)) + 
  ylim(c(0, 500000)) + 
  labs(subtitle="Area Vs Population", 
       y="Population", 
       x="Area", 
       title="Scatterplot", 
       caption = "Source: midwest")

plot(gg)
# Out:
# Warning message:
# "package 'ggalt' was built under R version 3.4.3"Warning message:
# "Removed 15 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 15 rows containing missing values (geom_point)."
# plot without title

# %%
#jitter plot
library(ggplot2)
data(mpg, package="ggplot2")

theme_set(theme_bw())  # pre-set the bw theme.
g <- ggplot(mpg, aes(cty, hwy))
g + geom_jitter(width = .5, size=1) +
  labs(subtitle="mpg: city vs highway mileage", 
       y="hwy", 
       x="cty", 
       title="Jittered Points")
# Out:
# plot without title

# %%
install.packages('ggExtra', repos='http://cran.us.r-project.org')
# Out:
# also installing the dependencies 'colourpicker', 'shinyjs'
# package 'colourpicker' successfully unpacked and MD5 sums checked
# package 'shinyjs' successfully unpacked and MD5 sums checked
# package 'ggExtra' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\swati\AppData\Local\Temp\Rtmp0WNGla\downloaded_packages

# %%
#Marginal Histogram using ggMarginal; geom_count: the bubble size increases if there are overlapping data points
library(ggplot2)
library(ggExtra)
data(mpg, package="ggplot2")

# Scatterplot
theme_set(theme_bw())
mpg_select <- mpg[mpg$hwy >= 35 & mpg$cty > 27, ]
g <- ggplot(mpg, aes(cty, hwy)) + 
  geom_count() + 
  geom_smooth(method="lm", se=F)

ggMarginal(g, type = "histogram", fill="transparent")
# Out:
# plot without title

# %%
install.packages('ggcorrplot', repos='http://cran.us.r-project.org')
# Out:
# package 'ggcorrplot' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\swati\AppData\Local\Temp\Rtmp0WNGla\downloaded_packages

# %%
#correlogram: to examine the correlation between continuous variables in the same dataframe
library(ggplot2)
library(ggcorrplot)

# Correlation matrix
data(mtcars)
corr <- round(cor(mtcars), 1)

ggcorrplot(corr, hc.order = TRUE, 
           type = "lower", 
           lab = TRUE, 
           lab_size = 3, 
           method="circle", 
           colors = c("tomato2", "white", "springgreen3"), 
           title="Correlogram of mtcars", 
           ggtheme=theme_bw)
# Out:
# plot without title

# %%
#Deviation: compare variation in values between small number of items with respect to a fixed reference
library(ggplot2)
theme_set(theme_bw())  

#data preparation
data("mtcars")  # load data
mtcars$`car name` <- rownames(mtcars)  # create new column for car names
mtcars$mpg_z <- round((mtcars$mpg - mean(mtcars$mpg))/sd(mtcars$mpg), 2)  # compute normalized mpg
mtcars$mpg_type <- ifelse(mtcars$mpg_z < 0, "below", "above")  # above / below avg flag
mtcars <- mtcars[order(mtcars$mpg_z), ]  # sort
mtcars$`car name` <- factor(mtcars$`car name`, levels = mtcars$`car name`)  # convert to factor to retain sorted order in plot.

# Diverging Barcharts
ggplot(mtcars, aes(x=`car name`, y=mpg_z, label=mpg_z)) + 
  geom_bar(stat='identity', aes(fill=mpg_type), width=.5)  +
  scale_fill_manual(name="Mileage", 
                    labels = c("Above Average", "Below Average"), 
                    values = c("above"="#00ba38", "below"="#f8766d")) + 
  labs(subtitle="Normalised mileage from 'mtcars'", 
       title= "Diverging Bars") + 
  coord_flip()
# Out:
# plot without title

# %%
#Ranking
library(ggplot2)
cty_mpg <- aggregate(mpg$cty, by=list(mpg$manufacturer), FUN=mean)
colnames(cty_mpg) <- c("make", "mileage")  # change column names
cty_mpg <- cty_mpg[order(cty_mpg$mileage), ]  # sort
cty_mpg$make <- factor(cty_mpg$make, levels = cty_mpg$make)  # to retain the order in plot.

theme_set(theme_bw())
ggplot(cty_mpg, aes(x=make, y=mileage)) + 
  geom_bar(stat="identity", width=.5, fill="springgreen3") + 
  labs(title="Ordered Bar Chart", 
       subtitle="Make Vs Avg. Mileage", 
       caption="source: mpg") + 
  theme(axis.text.x = element_text(angle=65, vjust=0.6))
# Out:
# plot without title

# %%
#Histogram
library(ggplot2)
theme_set(theme_classic())

# Histogram on a Continuous (Numeric) Variable
g <- ggplot(mpg, aes(displ)) + scale_fill_brewer(palette = "Spectral")

g + geom_histogram(aes(fill=class), 
                   binwidth = .2, 
                   col="black", 
                   size=.1) +  # change binwidth
  labs(title="Histogram: Engine Displacement across Vehicle Classes")
# Out:
# plot without title

# %%
#Pie Chart
library(ggplot2)
theme_set(theme_classic())
df <- as.data.frame(table(mpg$class))
colnames(df) <- c("class", "freq")
pie <- ggplot(df, aes(x = "", y=freq, fill = factor(class))) + 
  geom_bar(width = 1, stat = "identity") +
  theme(axis.line = element_blank(), 
        plot.title = element_text(hjust=0.5)) + 
  labs(fill="class", 
       x=NULL, 
       y=NULL, 
       title="Pie Chart of class", 
       caption="Source: mpg")

pie + coord_polar(theta = "y", start=0)
# Out:
# plot without title

# %%
#Spatial Visualization

# %%
library(ggplot2)
library(ggmap)
library(ggalt)

# Get Chennai's Coordinates --------------------------------
chennai <-  geocode("Chennai")  # get longitude and latitude
# Out:
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Chennai&sensor=false

# %%
# Google Hybrid Map
chennai_ggl_hybrid_map <- qmap("chennai", zoom=12, source = "google", maptype="hybrid")  


# Get Coordinates for Chennai's Places ---------------------
chennai_places <- c("Kolathur",
                    "Washermanpet",
                    "Royapettah",
                    "Adyar",
                    "Guindy")

places_loc <- geocode(chennai_places)  # get longitudes and latitudes
# Out:
# Map from URL : http://maps.googleapis.com/maps/api/staticmap?center=chennai&zoom=12&size=640x640&scale=2&maptype=hybrid&language=en-EN&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=chennai&sensor=false
# Warning message:
# "`panel.margin` is deprecated. Please use `panel.spacing` property instead"Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Kolathur&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Washermanpet&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Royapettah&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Adyar&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Guindy&sensor=false

# %%
# Google Hybrid Map ----------------------------------------
chennai_ggl_hybrid_map + geom_point(aes(x=lon, y=lat),
                                     data = places_loc, 
                                     alpha = 0.7, 
                                     size = 7, 
                                     color = "tomato") + 
                          geom_encircle(aes(x=lon, y=lat),
                                        data = places_loc, size = 2, color = "blue")
# Out:
# plot without title

# %%
vignette(all = TRUE)

# %%
#vignettes

# %%
#Citation: https://www.rdocumentation.org/packages/utils/versions/3.4.3/topics/vignette

## List vignettes from all *attached* packages
vignette(all = FALSE)

## List vignettes from all *installed* packages (can take a long time!):
vignette(all = TRUE)

## The grid intro vignette -- open it
vignette("grid") # calling print()

## The same (conditional on existence of the vignette).
## Note that 'package = *' is much faster in the case of many installed packages:
if(!is.null(v1 <- vignette("grid", package="grid"))) {
    v1 # calling print(.)
  str(v1)
}# if( has vignette "installed")
## A package can have more than one vignette (package grid has several):
vignette(package = "grid")
#if(interactive()) {
   ## vignette("rotated")
   ## The same, but without searching for it:
   vignette("rotated", package = "grid")
#}
# Out:
# List of 7
#  $ Package: chr "grid"
#  $ Dir    : chr "C:/Users/swati/Anaconda3/R/library/grid"
#  $ Topic  : chr "grid"
#  $ File   : chr "grid.Rnw"
#  $ Title  : chr "Introduction to grid"
#  $ R      : chr "grid.R"
#  $ PDF    : chr "grid.pdf"
#  - attr(*, "class")= chr "vignette"
